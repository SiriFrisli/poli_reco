# %%
import torch
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import os
import shutil

# %%
# Load CLIP model and processor
model_name = "openai/clip-vit-base-patch16"  # You can change this if you prefer another version
processor = CLIPProcessor.from_pretrained(model_name)
model = CLIPModel.from_pretrained(model_name)

# Ensure the model is in evaluation mode
model.eval()
# Out:
# c:\Users\sirifris\.conda\envs\poli_reco\lib\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sirifris\.cache\huggingface\hub\models--openai--clip-vit-base-patch16. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# CLIPModel(
#   (text_model): CLIPTextTransformer(
#     (embeddings): CLIPTextEmbeddings(
#       (token_embedding): Embedding(49408, 512)
#       (position_embedding): Embedding(77, 512)
#     )
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPSdpaAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (layer_norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#           (layer_norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16), bias=False)
#       (position_embedding): Embedding(197, 768)
#     )
#     (pre_layrnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPSdpaAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (visual_projection): Linear(in_features=768, out_features=512, bias=False)
#   (text_projection): Linear(in_features=512, out_features=512, bias=False)
# )

# %%
# List of prompts for known authority figures
authority_figures = [
    'politician',
    'government official',
    'Norwegian politician',
    'political figure',
    'authority figure',
    'people in suits',
    'man in suit',
    'woman in suit',
    'minister',
    'diplomat',
    'legislator',
    'public official'
]

# %%
# Folder where images are stored
image_folder = 'D:\\Images\\Covid\\output_images_detected'
classified_folder = 'D:\\Images\\Covid\\classified_authority'
no_authority_folder = 'D:\\Images\\Covid\\no_authority'

# %%
# Get list of image files in the folder
image_files = [f for f in os.listdir(image_folder) if f.endswith(('png', 'jpg', 'jpeg'))]

# Function to compute image embedding and match with text prompts
def get_image_embeddings(image_path):
    # Open image
    image = Image.open(image_path)
    
    # Preprocess the image and text (prompt)
    inputs = processor(text=authority_figures, images=image, return_tensors="pt", padding=True)
    
    # Generate embeddings
    with torch.no_grad():
        outputs = model(**inputs)
        
    image_embeddings = outputs.image_embeds  # Embedding for the image
    text_embeddings = outputs.text_embeds    # Embeddings for the text prompts
    
    return image_embeddings, text_embeddings

# Function to compute cosine similarity between image and text embeddings
from torch.nn.functional import cosine_similarity

def find_matching_prompts(image_embeddings, text_embeddings):
    # Calculate cosine similarities between image and text embeddings
    similarities = cosine_similarity(image_embeddings, text_embeddings)
    
    # Get the best match (the text with highest similarity)
    best_match_idx = similarities.argmax().item()  # Use .item() to convert to scalar
    best_similarity = similarities[best_match_idx].item()  # Access the similarity directly without indexing [0]
    
    return authority_figures[best_match_idx], best_similarity

# Process all images and save matches or "no authority" images
matches = []

for image_file in image_files:
    image_path = os.path.join(image_folder, image_file)
    
    # Get embeddings for the image and the text prompts
    image_embeddings, text_embeddings = get_image_embeddings(image_path)
    
    # Find the best matching authority figure
    best_match, similarity = find_matching_prompts(image_embeddings, text_embeddings)
    
    # If the similarity is above threshold, save it to the "classified_authority" folder
    if similarity > 0.25:  # You can adjust this threshold based on your preference
        classified_image_path = os.path.join(classified_folder, image_file)
        shutil.copy(image_path, classified_image_path)  # Copy image to classified folder
        matches.append((image_file, best_match, similarity))
    else:
        # If no authority figure is detected, save it to the "no_authority" folder
        no_authority_image_path = os.path.join(no_authority_folder, image_file)
        shutil.copy(image_path, no_authority_image_path)  # Copy image to "no_authority" folder

# Output matches
for match in matches:
    print(f"Image: {match[0]} | Matched Authority: {match[1]} | Similarity: {match[2]:.2f}")

print(f"\nTotal classified images: {len(matches)}")
print(f"Images with no authority detected: {len(image_files) - len(matches)}")
# Out:
# Image: FI_eGqhVIAM2x9Y.jpg | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: FIwO-xuXIAAYbbR.jpg | Matched Authority: Norwegian politician | Similarity: 0.30
# Image: FIvnj5sWQAsU0AJ.jpg | Matched Authority: Norwegian politician | Similarity: 0.30
# Image: FIk5v3tWUAAFOAB.jpg | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: FH5JjL_X0AAsIYH.jpg | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: FHtLz9tWUAUN4zx.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image:
jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: FHQGaQmUcAEJ3IV.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: FGn-0a1WUAMcaUk.jpg | Matched Authority: Norwegian politician | Similarity: 0.28
# Image: FGrFOO-XMAoQxBJ.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: FEu4SONXMA0modk.jpg | Matched Authority: authority figure | Similarity: 0.27
# Image: FBSNQoYWEAgfDr0.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: E_Kr33aWEAU4XMU.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: E_KgjaMXMAESnqL.jpg | Matched Authority: Norwegian politician | Similarity: 0.30
# Image: E_KbosiXMAIOwEi.jpg | Matched Authority: Norwegian politician | Similarity: 0.28
# Image: E_KbWaBWUAUad_A.jpg | Matched Authority: minister | Similarity: 0.25
# Image: E_KZyuoWEAQILxR.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: E_KZI8ZXIAMyu0B.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: E_KYC6TXoAAvBvR.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: E_KU3AgXsAM9DXt.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: E_KUKwGXEAEOMPw.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: E-yGS-AXMAAPUUs.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: E-nAYHcWUAA3Lbb.jpg | Matched Authority: minister | Similarity: 0.25
# Image: E9alusHXIBESFJC.jpg | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: E7ixbB8XoAYnXGI.jpg | Matched Authority: politician | Similarity: 0.26
# Image: E7esjXeXoAkPn5M.png | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: E4VSlv2XoAYjHo_.jpg | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: E4Hp0mcWUAIaaro.png | Matched Authority: Norwegian politician | Similarity: 0.28
# Image: E0NLhh5XEAEnyTu.jpg | Matched Authority: Norwegian politician | Similarity: 0.30
# Image: E0AZM1yXoAMv_FY.png | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: EpOxwiIXYAUUfwI.png | Matched Authority: Norwegian politician | Similarity: 0.28
# Image: Ef9Bm6gWsAERkeX.png | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: EhlYI9TX0AIUh36.jpg | Matched Authority: Norwegian politician | Similarity: 0.30
# Image: EjPOvPfWsAYv7EO.jpg | Matched Authority: Norwegian politician | Similarity: 0.28
# Image: EdI5YeNWkAMrr8x.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: EdIzf9WWoAQRp0r.jpg | Matched Authority: Norwegian politician | Similarity: 0.31
# Image: EYFq-XCWoAEOGiH.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: EW9SU4lWkAEWKU7.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: EWomStPXkAAlqjL.png | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: Fa72T0qX0AAdJFP.jpg | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: FYcLQ4eXgAExmmK.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: FKwCqeIWUAEkbPZ.jpg | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: FKn9C5pX0AsgEFa.jpg | Matched Authority: Norwegian politician | Similarity: 0.32
# Image: E5hxMukWUAIQJ5v.jpg | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: E3wxe6ZXMAA2pnf.jpg | Matched Authority: Norwegian politician | Similarity: 0.28
# Image: E3m9rgnWQAAHE38.jpg | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: E3Dq5xWXMAkBqRF.png | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: E3Dgn74WEAMP4qr.png | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: E2E3GrxXsAI_to1.png | Matched Authority: Norwegian politician | Similarity: 0.30
# Image: EytPVxQWgAoAqCp.jpg | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: EyXojj3XAAAVo_S.jpg | Matched Authority: Norwegian politician | Similarity: 0.28
# Image: EyFMxH9XEAMyQRw.png | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: Ex7PYygWQAIJrrT.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: ExQKXscXEAIoNPT.jpg | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: Ews19GKWQAE3dZI.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: EwT47VWWUAgIIOi.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: EtDq9iqXYAEkeVd.jpg | Matched Authority: Norwegian politician | Similarity: 0.30
# Image: Esb8euHXcAA-VxX.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: EsZ7VREXIAEHL85.jpg | Matched Authority: Norwegian politician | Similarity: 0.30
# Image: Ej52iW3X0AI2Pjf.png | Matched Authority: Norwegian politician | Similarity: 0.27
# Image: EjVRlthWoAIk-wN.png | Matched Authority: political figure | Similarity: 0.26
# Image: EgXp3MvXgAYd5iK.png | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: EfuKhd5WsAAbjQx.png | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: EYrp69cX0AASkGP.jpg | Matched Authority: Norwegian politician | Similarity: 0.30
# Image: EV9VEQIXsAEYwrF.jpg | Matched Authority: Norwegian politician | Similarity: 0.29
# Image: EVWX4QSWoAEMpZL.jpg | Matched Authority: Norwegian politician | Similarity: 0.28
# Image: EUl3kA6U4AA5XPI.jpg | Matched Authority: Norwegian politician | Similarity: 0.26
# Image: EUYT3TSWoAUePLP.png | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: ET5KQ4WXYAEmhBC.jpg | Matched Authority: Norwegian politician | Similarity: 0.25
# Image: ETUR_4NWsAMJXKt.jpg | Matched Authority: Norwegian politician | Similarity: 0.27
#
# Total classified images: 5440
# Images with no authority detected: 8998
